# %%
import os
import subprocess
import shutil
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
import time
import pyspark
import re
from pyspark.ml.feature import MinHashLSH
from pyspark.ml.feature import CountVectorizer,  IDF, CountVectorizerModel, Tokenizer, RegexTokenizer, StopWordsRemover
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql import Row
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)
pd.reset_option('display.max_rows')
from itertools import compress 
from pyspark.sql.functions import *
from pyspark.sql.types import *
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings(action='ignore')

# %%
spark = SparkSession.builder.appName("Read Parquet File").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)
spark.conf.set("spark.sql.repl.eagerEval.maxNumRows", 10000)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/03/11 04:36:41 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/03/11 04:36:42 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/03/11 04:36:42 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/03/11 04:36:42 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %%
# check bucket to load file from
# !hadoop fs -ls 'gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample' | head -n 6
# Out:
# Found 4413 items
# -rwx------   3 root root          0 2023-03-11 01:52 gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample/_SUCCESS
# -rwx------   3 root root       5298 2023-03-11 01:45 gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample/part-00000-77928e78-5b6d-422d-8d0d-403d9bfdc6ed-c000.snappy.parquet
# -rwx------   3 root root       5763 2023-03-11 01:45 gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample/part-00001-77928e78-5b6d-422d-8d0d-403d9bfdc6ed-c000.snappy.parquet
# -rwx------   3 root root       5070 2023-03-11 01:45 gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample/part-00003-77928e78-5b6d-422d-8d0d-403d9bfdc6ed-c000.snappy.parquet
# -rwx------   3 root root       5672 2023-03-11 01:45 gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample/part-00004-77928e78-5b6d-422d-8d0d-403d9bfdc6ed-c000.snappy.parquet

# %%
# %%time
# read the parque sample_file 
sample_df = spark.read.format('parquet').load('gs://msca-bdp-students-bucket/shared_data/danilm/final_df_sample')
# Out:
# CPU times: user 8.61 ms, sys: 130 µs, total: 8.74 ms
# Wall time: 7.4 s

# %%
# count of the dataframe
sample_df.count()
# Out:
# 9567

# %%
# testing
sample_df.limit(10).toPandas()
# Out:
#                         name      screen_name  verified  friends_count  \
# 0                 Live Agile       agile_live     False           3745
# 1                          .     thebongolese     False            980
# 2   🇺🇲 Ultra MAGA Trump Girl  TrumpGi79056629     False           1146
# 3                   Lou Wall  LouWall48323834     False            189
# 4                  Astrosfan    WilliamHartly     False            149
# 5               candyhorner1  tupelohoney2000     False            201
# 6                  WestCoast      WestCoa2054     False             17
# 7                      Cakes        cakes_iam     False           7207
# 8  karen petersen #notakaren     karenApete90     False            100
# 9            Barbara Freethy   BarbaraFreethy     False           1188
#
#    followers_count             location  \
# 0             3410  Portsmouth, England
# 1             8266               Africa
# 2              691                 None
# 3              268                 None
# 4               11                 None
# 5              663                 None
# 6              338                 None
# 7             6977        Las Vegas, NV
# 8               35                 None
# 9              406                 None
#
#                                                                                                                                                         description  \
# 0  #Alcoholic #Anxious #Sober. After realising the deep effects of anxiety and addiction I’ve spent years identifying how to win and regain my life. #RecoveryPosse
# 1                                                                                            Professional baby girl, Travel and Documentary Photographer and Auteur
# 2                                                                                                    Conservative, America first, God fearing Patriot.\n 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇲
# 3                                                                   I believe in the Charter of Rights and Freedoms for all Canadians. NO DM’s or I will block you.
# 4                                                                                                                                                              None
# 5                                                                                                                                                              None
# 6                                                                                                                                                              None
# 7                                     healthcare worker. Wife/mom/Moms Demand volunteer/ views & uterus are my own. she/ her #Resist #EndGunViolence #GetVaccinated
# 8                                                                                                                                               Mama, wife, teacher
# 9     #1 NYT Bestselling Author of contemporary romance and romantic suspense. Tennis player, book lover, cat owner, mom, and sometimes watches too much reality TV
#
#    favourites_count  reply_count  retweet_count  \
# 0             11122          0.0           14.0
# 1             15813          NaN            NaN
# 2              5972        201.0         1629.0
# 3             14939        203.0         1647.0
# 4              1084          0.0            1.0
# 5            204960          2.0           15.0
# 6               145          NaN            NaN
# 7            183416        449.0         2762.0
# 8             39710        450.0         2770.0
# 9              5511        451.0         2774.0
#
#                        created_at  \
# 0  Mon Apr 20 11:41:49 +0000 2020
# 1  Thu Apr 12 15:44:57 +0000 2012
# 2  Mon Apr 25 21:43:27 +0000 2022
# 3  Mon Jan 31 23:05:53 +0000 2022
# 4  Thu Jul 14 16:38:31 +0000 2022
# 5  Sat Jun 02 02:24:57 +0000 2012
# 6  Wed Nov 02 00:39:41 +0000 2022
# 7  Tue May 26 00:04:07 +0000 2009
# 8  Fri Feb 06 04:06:25 +0000 2015
# 9  Fri Dec 04 04:24:47 +0000 2020
#
#                                                                                                                                                                                                                                                                                           tweet_text
# 0                         @ExtinctionR I'm in Pakistan where 33 million people have been displaced....so yeah. I'm on not on edge. I've actively tipped over. Screaming about climate change for years only to watch in mute despair as half the country sinks. Bridges, roads, homes, schools gone.
# 1                                                                                                                                                                  Randomly thinking of the Zimbabwe UFO Sighting in 1994. Aliens showed up in a school and told the kids about  “climate change” ….
# 2                                      BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 3                                      BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 4                                                                                                    Radical tree hugger @krismayes says Climate Change is her top priority. \n\nShe has devoted her life to ending fossil fuels - we have high gas prices because of radical professors like Mayes.
# 5                                                                                                    Radical tree hugger @krismayes says Climate Change is her top priority. \n\nShe has devoted her life to ending fossil fuels - we have high gas prices because of radical professors like Mayes.
# 6                                                                   Are the Clintons and Obamas or Oprah going to open their beach homes for these guys ?                  Miami should begin 'preparing for evacuation' due to climate change, Berkeley professor argues\n\nhttps://t.co/yltIn0KEHq
# 7  Refresher on what a “pro-life” agenda ACTUALLY looks like:\n\n- gun safety laws\n- taking action on climate change\n- protecting LGBT rights\n- healthcare for all\n- expanding pre-natal care\n- expanding mental healthcare \n- expanding childcare\n- universal preschool\n- free school meals
# 8  Refresher on what a “pro-life” agenda ACTUALLY looks like:\n\n- gun safety laws\n- taking action on climate change\n- protecting LGBT rights\n- healthcare for all\n- expanding pre-natal care\n- expanding mental healthcare \n- expanding childcare\n- universal preschool\n- free school meals
# 9  Refresher on what a “pro-life” agenda ACTUALLY looks like:\n\n- gun safety laws\n- taking action on climate change\n- protecting LGBT rights\n- healthcare for all\n- expanding pre-natal care\n- expanding mental healthcare \n- expanding childcare\n- universal preschool\n- free school meals

# %%
# casting varriables to the appropriate data type
sample_df = sample_df.withColumn('reply_count', sample_df['reply_count'].cast(IntegerType()))
sample_df = sample_df.withColumn('retweet_count', sample_df['retweet_count'].cast(IntegerType()))
sample_df = sample_df.withColumn('friends_count', sample_df['friends_count'].cast(IntegerType()))
sample_df = sample_df.withColumn('retweet_count', sample_df['retweet_count'].cast(IntegerType()))
sample_df = sample_df.withColumn('favourites_count', sample_df['favourites_count'].cast(IntegerType()))

# %%
# validating the casts
sample_df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- screen_name: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- friends_count: integer (nullable = true)
#  |-- followers_count: long (nullable = true)
#  |-- location: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- favourites_count: integer (nullable = true)
#  |-- reply_count: integer (nullable = true)
#  |-- retweet_count: integer (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- tweet_text: string (nullable = true)

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Top Twitterers

# %%
# create a new column with concatenated name, screen_name entries
sample_df =  sample_df.withColumn('name_username', concat(col('name'),lit(', '),col('screen_name')))
sample_df.limit(5).toPandas()
# Out:
#                        name      screen_name  verified  friends_count  \
# 0                Live Agile       agile_live     False           3745
# 1                         .     thebongolese     False            980
# 2  🇺🇲 Ultra MAGA Trump Girl  TrumpGi79056629     False           1146
# 3                  Lou Wall  LouWall48323834     False            189
# 4                 Astrosfan    WilliamHartly     False            149
#
#    followers_count             location  \
# 0             3410  Portsmouth, England
# 1             8266               Africa
# 2              691                 None
# 3              268                 None
# 4               11                 None
#
#                                                                                                                                                         description  \
# 0  #Alcoholic #Anxious #Sober. After realising the deep effects of anxiety and addiction I’ve spent years identifying how to win and regain my life. #RecoveryPosse
# 1                                                                                            Professional baby girl, Travel and Documentary Photographer and Auteur
# 2                                                                                                    Conservative, America first, God fearing Patriot.\n 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇲
# 3                                                                   I believe in the Charter of Rights and Freedoms for all Canadians. NO DM’s or I will block you.
# 4                                                                                                                                                              None
#
#    favourites_count  reply_count  retweet_count  \
# 0             11122          0.0           14.0
# 1             15813          NaN            NaN
# 2              5972        201.0         1629.0
# 3             14939        203.0         1647.0
# 4              1084          0.0            1.0
#
#                        created_at  \
# 0  Mon Apr 20 11:41:49 +0000 2020
# 1  Thu Apr 12 15:44:57 +0000 2012
# 2  Mon Apr 25 21:43:27 +0000 2022
# 3  Mon Jan 31 23:05:53 +0000 2022
# 4  Thu Jul 14 16:38:31 +0000 2022
#
#                                                                                                                                                                                                                                                                    tweet_text  \
# 0  @ExtinctionR I'm in Pakistan where 33 million people have been displaced....so yeah. I'm on not on edge. I've actively tipped over. Screaming about climate change for years only to watch in mute despair as half the country sinks. Bridges, roads, homes, schools gone.
# 1                                                                                                                                           Randomly thinking of the Zimbabwe UFO Sighting in 1994. Aliens showed up in a school and told the kids about  “climate change” ….
# 2               BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 3               BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 4                                                                             Radical tree hugger @krismayes says Climate Change is her top priority. \n\nShe has devoted her life to ending fossil fuels - we have high gas prices because of radical professors like Mayes.
#
#                                name_username
# 0                     Live Agile, agile_live
# 1                            ., thebongolese
# 2  🇺🇲 Ultra MAGA Trump Girl, TrumpGi79056629
# 3                  Lou Wall, LouWall48323834
# 4                   Astrosfan, WilliamHartly

# %%
# Top 30 Highest Retweets
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_retweets = sample_df.groupby('name_username','description').agg(sum('retweet_count')).orderBy('sum(retweet_count)',ascending=False).limit(30).toPandas()

# %%
# Investigate profile descriptions to comprehend what is the background of the people who are at the top of the metric aggregation
top_30_retweets
# Out:
#                                       name_username  \
# 0               mary margaret mucha, marymargaret70
# 1                          heather, heathernataliee
# 2                        VinceMeat, exponentbracket
# 3                                #BLM, acharya_dude
# 4                                    SRPeel, SRPeel
# 5              Marianne Collins ☮️, collinsmarianne
# 6      Dr. Lynn Roseberry ☮️ 🌻🇺🇸🇩🇰🇪🇺, LynnRoseberry
# 7          Linda Conner💉💉💉💉Democrat,🌊🌊🌊, Jazzlyn317
# 8                  🌞zusiesunshine 🌻😻, zusiesunshine
# 9                                   nest DC, NestDC
# 10        Shadowboxing The Apocalypse, Wharfrat2004
# 11  Trevor "Trev" McKee Achilles 🇺🇸 🇺🇦, MrTAchilles
# 12                           Andy Miller, jamaustex
# 13                             Per M. Koch, perkoch
# 14                      Cassidy Brown, TheSasckMask
# 15                            wvbobbi, hannah_bobbi
# 16                                 Leo, Leo97057749
# 17         For the Many, Not a Clue, PoliticsDoings
# 18                          Rajesh Swamy, raj0swamy
# 19                Cynthia Elliott 🌈🚴🏼‍♂️, gotogal36
# 20                               NONIE G, nonononie
# 21                               RandyH57, H57Randy
# 22               Stephanie Michelle 🦦, Stepherrr425
# 23                                 anju, anjuphobic
# 24                                   NDBW, bwillowb
# 25               #Sistah_Shelina 🌻🎸, Sistah_Shelina
# 26                          Rada Dagher, RadaDagher
# 27      Paulakillman@Loving the ocean, paulakillman
# 28                                 ChicMike, ChyMik
# 29                                   VYC, v_e_e_e_e
#
#                                                                                                                                                           description  \
# 0                                                                                                                                                                None
# 1                                                                                                                                                                   🙂
# 2                   Vince\n| hi i'm a four kinnie \n| he/they \n| creator of Diverse Articles | i draw cool things \n| 16\n| art tag: #vinceart\n@foursymoved ILYSM 💋
# 3                                                                                                 Tweets abt transportation and land use. Tweets are my own opinions.
# 4                                                                                                            Father of 2. Lifelong political junkie. Stroke survivor.
# 5                                                                                Love plants, tree and nature! Love to pray and believe ALL people are created equal.
# 6                             Psychotherapist. Diversity and Inclusion Consultant. I tweet about #gender #diversity #humanrights #ruleoflaw US UK DK politics she/her
# 7                    70 + Baby boomer ,Retired Nurse ,married ,grandmother and anti trump and❤ Bidden Harris!!grandmother to 2 Sailors Resister!http://BLM.No DMs!🌊🇺🇲
# 8                        Love kitties. Registered Independent, but have never & would never vote Red…ever. Never trump. #SaveOurDemocracy #AbolishTheElectoralCollege
# 9                                                         NEST DC is Washington’s only boutique property management and design company that delights in every detail.
# 10                                                                     Oh well a touch of grey\nKind of suits you anyway\nThat was all I had to say\nAnd it's alright
# 11   #ForUkraine, #Resist, #BLM, #Vaxxed, liberal, autistic, kidney transplant survivor, political nerd, mental health advocate, fighter for equality, truth, justice
# 12         Father, husband, nonprofit, advocate, craftsman, artist, baker, runner, liberal & nerdist. Just trying to figure it all out. #BeKind #stoic #GetVaccinated
# 13                                      Research and innovation policy, culture, science, search engines and social media. Editor of Forskningspolitikk at @NIFU01 🇺🇦
# 14                                               Colorado|Libra|Let’s Go Duke|Boomer Sooner|Buckeye Nation|Autism|Music nerd|Pro wrestling fan|Reality TV enthusiast|
# 15                                                                                                                                                               None
# 16                                                                                                                                                          21 He/Him
# 17                                                    Politics addict who believes that politics matters. Pro-honesty and integrity in public life, anti-antipolitics
# 18                                                                                                                                                               None
# 19                                                                      Over educated, community organizer & radical urban guerrilla, who turns a wrench for a living
# 20                                                                                                                                             cheeki cha cha bom bom
# 21  Widower, Compassionate, Empath, Animal Lover, Loves Helping Others, 2 Time Cancer Survivor, Coffee Addict.    $rmh1957\nInstagram: @rmh19571\nSnapChat: rm_jh2020
# 22                      She/her. #BlackLivesMatter THIS IS ONCE AGAIN A @jonasbrothers STAN ACCOUNT. With some of this stuff: RT/AH/Disnerd/Gilmore/Jets/many others.
# 23                                                                                                                                sitting pretty in the prime of life
# 24                                                                                                                                                               None
# 25          Free-spirit, sports & 🤘🏼music fan, book nerd, retweeter and supporter of taco 🌮 trucks on every corner. #VoteBlue #FBResist #NOLISTS #ERA 💪🏼#WeThePeople🗽
# 26   Public Health and Health Equity Researcher, Social Scientist, Scholarly Works @ https://scholar.google.com/citations?user=SLVK3ZkAAAAJ&hl=en opinions are my own
# 27                                                                      Mother of three grandmother of seven Live on the gulf coast. Going to the beach and I love it
# 28                                       Liberal. Help people get informed. Be cautious: some Twitter users post misinformation and propaganda, and oppose democracy.
# 29                                                                                      Grateful mom. Liberal feminist. Former foodie. Views are my own. she/her/hers
#
#     sum(retweet_count)
# 0                20871
# 1                20865
# 2                20849
# 3                20834
# 4                20819
# 5                20817
# 6                20771
# 7                20762
# 8                20638
# 9                20631
# 10               20564
# 11               20510
# 12               20428
# 13               20377
# 14               20365
# 15               20284
# 16               20259
# 17               20218
# 18               20216
# 19               20154
# 20               20094
# 21               20089
# 22               20056
# 23               19966
# 24               19932
# 25               19922
# 26               19906
# 27               19887
# 28               19816
# 29               19811

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=top_30_retweets['name_username'], width=top_30_retweets['sum(retweet_count)'])
plt.xlabel('Total retweets')
plt.xlim(top_30_retweets['sum(retweet_count)'].min()-200, top_30_retweets['sum(retweet_count)'].max()+200)
plt.xticks(range(top_30_retweets['sum(retweet_count)'].min(), top_30_retweets['sum(retweet_count)'].max(), 150))
plt.ylabel('name_username')
plt.title('Top 30 retweeted users')
plt.gca().invert_yaxis()
plt.show()

# %%
# Top 30 Highest Replies
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_replies = sample_df.groupby('name_username','description').agg(sum('reply_count')).orderBy('sum(reply_count)',ascending=False).limit(30).toPandas()

# %%
# Investigate profile descriptions to comprehend what is the background of the people who are at the top of the metric aggregation
top_30_replies
# Out:
#                                       name_username  \
# 0               mary margaret mucha, marymargaret70
# 1                          heather, heathernataliee
# 2                        VinceMeat, exponentbracket
# 3                                #BLM, acharya_dude
# 4              Marianne Collins ☮️, collinsmarianne
# 5                                    SRPeel, SRPeel
# 6      Dr. Lynn Roseberry ☮️ 🌻🇺🇸🇩🇰🇪🇺, LynnRoseberry
# 7          Linda Conner💉💉💉💉Democrat,🌊🌊🌊, Jazzlyn317
# 8                  🌞zusiesunshine 🌻😻, zusiesunshine
# 9                                   nest DC, NestDC
# 10        Shadowboxing The Apocalypse, Wharfrat2004
# 11                           Andy Miller, jamaustex
# 12                             Per M. Koch, perkoch
# 13                      Cassidy Brown, TheSasckMask
# 14                            wvbobbi, hannah_bobbi
# 15                                 Leo, Leo97057749
# 16                          Rajesh Swamy, raj0swamy
# 17         For the Many, Not a Clue, PoliticsDoings
# 18  Trevor "Trev" McKee Achilles 🇺🇸 🇺🇦, MrTAchilles
# 19                Cynthia Elliott 🌈🚴🏼‍♂️, gotogal36
# 20                               NONIE G, nonononie
# 21                               RandyH57, H57Randy
# 22               Stephanie Michelle 🦦, Stepherrr425
# 23                                 anju, anjuphobic
# 24                                   NDBW, bwillowb
# 25               #Sistah_Shelina 🌻🎸, Sistah_Shelina
# 26                          Rada Dagher, RadaDagher
# 27      Paulakillman@Loving the ocean, paulakillman
# 28                                 ChicMike, ChyMik
# 29               Dr. Jennifer Mitchell, charnamarna
#
#                                                                                                                                                           description  \
# 0                                                                                                                                                                None
# 1                                                                                                                                                                   🙂
# 2                   Vince\n| hi i'm a four kinnie \n| he/they \n| creator of Diverse Articles | i draw cool things \n| 16\n| art tag: #vinceart\n@foursymoved ILYSM 💋
# 3                                                                                                 Tweets abt transportation and land use. Tweets are my own opinions.
# 4                                                                                Love plants, tree and nature! Love to pray and believe ALL people are created equal.
# 5                                                                                                            Father of 2. Lifelong political junkie. Stroke survivor.
# 6                             Psychotherapist. Diversity and Inclusion Consultant. I tweet about #gender #diversity #humanrights #ruleoflaw US UK DK politics she/her
# 7                    70 + Baby boomer ,Retired Nurse ,married ,grandmother and anti trump and❤ Bidden Harris!!grandmother to 2 Sailors Resister!http://BLM.No DMs!🌊🇺🇲
# 8                        Love kitties. Registered Independent, but have never & would never vote Red…ever. Never trump. #SaveOurDemocracy #AbolishTheElectoralCollege
# 9                                                         NEST DC is Washington’s only boutique property management and design company that delights in every detail.
# 10                                                                     Oh well a touch of grey\nKind of suits you anyway\nThat was all I had to say\nAnd it's alright
# 11         Father, husband, nonprofit, advocate, craftsman, artist, baker, runner, liberal & nerdist. Just trying to figure it all out. #BeKind #stoic #GetVaccinated
# 12                                      Research and innovation policy, culture, science, search engines and social media. Editor of Forskningspolitikk at @NIFU01 🇺🇦
# 13                                               Colorado|Libra|Let’s Go Duke|Boomer Sooner|Buckeye Nation|Autism|Music nerd|Pro wrestling fan|Reality TV enthusiast|
# 14                                                                                                                                                               None
# 15                                                                                                                                                          21 He/Him
# 16                                                                                                                                                               None
# 17                                                    Politics addict who believes that politics matters. Pro-honesty and integrity in public life, anti-antipolitics
# 18   #ForUkraine, #Resist, #BLM, #Vaxxed, liberal, autistic, kidney transplant survivor, political nerd, mental health advocate, fighter for equality, truth, justice
# 19                                                                      Over educated, community organizer & radical urban guerrilla, who turns a wrench for a living
# 20                                                                                                                                             cheeki cha cha bom bom
# 21  Widower, Compassionate, Empath, Animal Lover, Loves Helping Others, 2 Time Cancer Survivor, Coffee Addict.    $rmh1957\nInstagram: @rmh19571\nSnapChat: rm_jh2020
# 22                      She/her. #BlackLivesMatter THIS IS ONCE AGAIN A @jonasbrothers STAN ACCOUNT. With some of this stuff: RT/AH/Disnerd/Gilmore/Jets/many others.
# 23                                                                                                                                sitting pretty in the prime of life
# 24                                                                                                                                                               None
# 25          Free-spirit, sports & 🤘🏼music fan, book nerd, retweeter and supporter of taco 🌮 trucks on every corner. #VoteBlue #FBResist #NOLISTS #ERA 💪🏼#WeThePeople🗽
# 26   Public Health and Health Equity Researcher, Social Scientist, Scholarly Works @ https://scholar.google.com/citations?user=SLVK3ZkAAAAJ&hl=en opinions are my own
# 27                                                                      Mother of three grandmother of seven Live on the gulf coast. Going to the beach and I love it
# 28                                       Liberal. Help people get informed. Be cautious: some Twitter users post misinformation and propaganda, and oppose democracy.
# 29                         bisexual associate prof @ union college; modern and contemporary lit, sexuality and queer studies; black trans lives matter; she/her/hers.
#
#     sum(reply_count)
# 0               2113
# 1               2112
# 2               2106
# 3               2105
# 4               2105
# 5               2105
# 6               2103
# 7               2103
# 8               2070
# 9               2065
# 10              2061
# 11              2035
# 12              2027
# 13              2024
# 14              2014
# 15              2009
# 16              2002
# 17              2002
# 18              1999
# 19              1993
# 20              1983
# 21              1983
# 22              1981
# 23              1980
# 24              1978
# 25              1978
# 26              1976
# 27              1974
# 28              1974
# 29              1974

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=top_30_replies['name_username'], width=top_30_replies['sum(reply_count)'])
plt.xlabel('Total replies')
plt.xlim(top_30_replies['sum(reply_count)'].min()-50, top_30_replies['sum(reply_count)'].max()+50)
plt.xticks(range(top_30_replies['sum(reply_count)'].min(), top_30_replies['sum(reply_count)'].max(), 10))
plt.ylabel('name_username')
plt.title('Top 30 replied to users')
plt.gca().invert_yaxis()
plt.show()

# %%
# Top 30 most followed twitterers
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_followers = sample_df.groupby('name_username','description').agg(sum('followers_count')).orderBy('sum(followers_count)',ascending=False).limit(30).toPandas()

# %%
top_30_followers
# Out:
#                                    name_username  \
# 0                                     NDTV, ndtv
# 1                      Hindustan Times, htTweets
# 2                      Mark Ruffalo, MarkRuffalo
# 3                               Gizmodo, Gizmodo
# 4                  Education Week, educationweek
# 5                           NowThis, nowthisnews
# 6                           NowThis, nowthisnews
# 7                      Forbes India, ForbesIndia
# 8                  The New Vision, newvisionwire
# 9                  The National, TheNationalNews
# 10          Reuters Science News, ReutersScience
# 11                                    GOOD, good
# 12                     Globalnews.ca, globalnews
# 13  J.D.™🦄 (🐯Spirit🐢) Nlandu 🇨🇩 🇧🇪 🇫🇷 🇺🇸, iownjd
# 14                           The Quint, TheQuint
# 15                    BBC Radio 5 Live, bbc5live
# 16                     Tom Nichols, RadioFreeTom
# 17                  Shannon Watts, shannonrwatts
# 18                     Raza Ahmad Rumi, Razarumi
# 19                 Daily Maverick, dailymaverick
# 20                         Ada Derana, adaderana
# 21                     Amitav Ghosh, GhoshAmitav
# 22            Inside Climate News, insideclimate
# 23                   UK Space Agency, spacegovuk
# 24               Governor Phil Murphy, GovMurphy
# 25                 Columbia University, Columbia
# 26                 Columbia University, Columbia
# 27            Prof Michael E. Mann, MichaelEMann
# 28               Urban Television, UrbanTVUganda
# 29                         Nadia Jamil, NJLahori
#
#                                                                                                                                                               description  \
# 0                                                              Breaking news alerts from India.\n\nInstagram: http://instagram.com/ndtv\nYouTube: http://youtube.com/ndtv
# 1                                                                One of India's largest media companies. Latest news from around the world. Retweets are not endorsements
# 2                  A husband, father, actor, director, & a climate justice advocate with an eye out for a better, brighter, cleaner, & more hopeful future for all of us.
# 3                                                                                                                                                 We come from the future
# 4   Inspiring you through K-12 news, analysis, and opinion. Empowering you to make a difference in your community.\n\nSign up for our newsletter: https://t.co/rFHMPLoZtc
# 5                                                                                       Stories that move. Subscribe to our daily newsletter: http://go.nowth.is/knowthis
# 6                                                                                Stories that move. Subscribe to our daily newsletter: http://go.nowth.is/knowthis_twitt…
# 7         Bringing you the best conversations on Indian and international business, in alliance with @Forbes. Run by our journalists. Read more at http://forbesindia.com
# 8                              Breaking News, Current Events and News Analysis from Uganda's Leading Daily.  #VisionUpdates\n\n#EPaper - http://epapers.visiongroup.co.ug
# 9                  The world has borders. Our stories don't.\n• Global, MENA and UAE news\n• Middle East explained\n• Business \n• Sport\n• Arts and lifestyle\n• Opinion
# 10             From newly charted astronomical anomalies at the far reaches of the universe to the rise of nanotechnology, nobody covers science like http://Reuters.com.
# 11                                                                                                                            Understand the world so you can improve it.
# 12                   Breaking Canadian news with a fresh perspective on local & international headlines 🚨YT: http://bit.ly/2rGQmtG 🚨 TikTok: http://vm.tiktok.com/sH5WGb/
# 13              A✍️@nerdinajock🚀CEO👨🏾‍💼@Twitter (@iOwnDigital™️)—🧢Mogul—Speaker and perpetual optimist, learn—Be cute, but real in this ugly world ✨Ask🗺J.D.🦚@letterstoJD
# 14                                                                           Mobile-first digital news platform. | SUBSCRIBE TO NEWSLETTER: http://thequint.com/subscribe
# 15                              The voice of the UK and the @BBC's home of breaking news and sport. Tweet @bbc5live to contact the studio directly. Listen on @BBCSounds.
# 16                                                                          Staff writer at @TheAtlantic. Curmudgeon. Cat guy. Democracy enthusiast, defender of experts.
# 17       Founder of @MomsDemand, grassroots army of @Everytown / "Fight Like a Mother" author / Boards @WeAdvancePeace, @EmergeAmerica / On IG and TikTok @ shannonrwatts
# 18           Journalism, public policy, intl development—Books: @DelhibyHeart; The Fractious Path; Being Pakistani; Identity, Faith & Conflict; The Role of Public Admin.
# 19                              The need to Defend Truth has never been greater. Support free, fair, fearless reporting. Become a Maverick Insider: http://bit.ly/2OoKhhg
# 20                                                   A premier breaking news website offering news from Sri Lanka in English, Sinhala and Tamil. WEB: http://adaderana.lk
# 21                                                                                                                        Author most recently of 'The Nutmeg's Curse'...
# 22              Pulitzer Prize-winning, nonprofit, non-partisan newsroom dedicated to covering climate, energy and the environment. Our newsletter: http://bit.ly/2NcWMpo
# 23                                                                                              We inspire and lead the UK in space to benefit our planet and its people.
# 24                                                                56th Governor of the Garden State. Advancing opportunity and affordability for every New Jersey family.
# 25                                                                                              The official Twitter feed of Columbia University in the City of New York.
# 26                                                                                              The official twitter feed of Columbia University in the City of New York.
# 27         Scientist & author; Distinguished Prof of Atmospheric Science & Director of Earth System Science Center, Penn State; National Academy of Sciences; Tyler Prize
# 28                                              Tubaale! The vibe continues on our Instagram: http://instagram.com/urbantvuganda and TikTok: http://tiktok.com/@urbantvug
# 29       Actor/Activist:ChildProtection/Survived2Thrive:Cancer,CSA/MasterPractitioner:NLP,Hypnotherapy,TLT/AOLvolunteer/HappilyClueless/Learning/Literature/Cosmos/Nature
#
#     sum(followers_count)
# 0               17066504
# 1                8692930
# 2                8378012
# 3                2785899
# 4                2761422
# 5                2744481
# 6                2743303
# 7                1282802
# 8                1224977
# 9                1109355
# 10                997613
# 11                835422
# 12                813566
# 13                797240
# 14                745344
# 15                683440
# 16                640498
# 17                565778
# 18                557503
# 19                547263
# 20                525107
# 21                469086
# 22                462120
# 23                453063
# 24                447509
# 25                447088
# 26                444203
# 27                425094
# 28                386116
# 29                379984

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=top_30_followers['name_username'], width=top_30_followers['sum(followers_count)'])
plt.xlabel('Total followers(millions)')
plt.xlim(top_30_followers['sum(followers_count)'].min()-2000000, top_30_followers['sum(followers_count)'].max()+2000000)
plt.xticks(range(top_30_followers['sum(followers_count)'].min(), top_30_followers['sum(followers_count)'].max(), 2000000))
plt.ylabel('name_username')
plt.title('Top 30 most followed twitterers')
plt.gca().invert_yaxis()
plt.show()

# %%
# Top 30 most befriended twitterers
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_friends = sample_df.groupby('name_username','description').agg(sum('friends_count')).orderBy('sum(friends_count)',ascending=False).limit(30).toPandas()

# %%
# Investigate profile descriptions to comprehend what is the background of the people who are at the top of the metric aggregation
top_30_friends
# Out:
#                                                   name_username  \
# 0                  J.D.™🦄 (🐯Spirit🐢) Nlandu 🇨🇩 🇧🇪 🇫🇷 🇺🇸, iownjd
# 1                                              AppSame, AppSame
# 2                                     Saleemul Huq, SaleemulHuq
# 3   Furniture Assembly Experts - DC MD VA Baltimore, DC__MOVERS
# 4                                        TzConnect, tzDiscovery
# 5                                박성율- #ClimateEmergency, ppptec
# 6                                     Mesa🇧🇦🇺🇦🇺🇸, ElectBlue2022
# 7                              #VotingRightsAct, JesusNarrowWay
# 8                                   David  Benjamin, thetoyman1
# 9                                 🇺🇸 Truth over Lies 🇺🇸, monnj6
# 10        FE News - The #FutureofEducation News Channel, FENews
# 11             Scotty🚀 🗳 4 Days Til Midterms 🇺🇦 🌊🌻, MrScottLads
# 12                              👑💥 Serenity 💥👑, polishprincessh
# 13                                 ⭐Eagle One⭐, EagleInTheCloud
# 14                                       Asher Wolf, Asher_Wolf
# 15                                          Alesha, aleshadalin
# 16                             Texas Tech University, TexasTech
# 17                               SmartDissent.com, smartdissent
# 18                 Lava Kafle: #Software #global #Nepal, lkafle
# 19                         Old Lefty White Man, OldWhiteManLfty
# 20                                non-ficshawn🌵, ShawnInArizona
# 21                               Randall Nicholas, rrnicholas22
# 22                          Allen Y. Tien MD MHS 田一彦, allentien
# 23    ULTRA MAGA KEVIN WITH STOLEN NUCLEAR CODES, kevinhaddad08
# 24                        Nabil H The Peacemaker ⚛️☮️, inabster
# 25                     Farrell Ross I FOLLOW BACK, haveaconcern
# 26                      Robbin ¯\(ツ) ⁄ ¯🧚🏼‍♀️🇺🇦🌻, RaeMargaret61
# 27                                             TPBlue💔, TPBlue4
# 28                             #VotingRightsAct, JesusNarrowWay
# 29              Trevor "Trev" McKee Achilles 🇺🇸 🇺🇦, MrTAchilles
#
#                                                                                                                                                                 description  \
# 0                 A✍️@nerdinajock🚀CEO👨🏾‍💼@Twitter (@iOwnDigital™️)—🧢Mogul—Speaker and perpetual optimist, learn—Be cute, but real in this ugly world ✨Ask🗺J.D.🦚@letterstoJD
# 1                                                                                                      AppSame is about to stand up to the News bully and fight for America
# 2                                                           Director, @ICCCAD and Senior Associate @IIED. Work on adaptation to climate change. Views presented are my own.
# 3                Residential & Commercial furniture assembly - moving  - Installation - junk furniture removal - in Washington DC - Maryland - Virginia - CALL 240-714-3649
# 4                                                                                                                  Get live Tweets of current issues and share with friends
# 5                                                         #ActOnClimate.\n사람답게 살기/느리게 살기/소금으로 살기/\n토지난민연대/  원주녹색연합/\nClimate- and environmental activist\n#ClimateEmergency
# 6                                            #DemVoice1 (FOUNDER) Democrats Activist Group 💙Being a Democrat is a lifestyle 💙To learn more about #DemVoice1 send me DM 🇺🇸🇧🇦
# 7                     @staceyabrams @CheriBeasleyNC @ValDemings @DemocraticAgs @DemsofState @Dlcc @JonesforAR @senatedems @DemMayors @MichelleVForTx @demgovs @AaronDFordNV
# 8                         Media Consultant, Lakers Fan, Vegas Expert/Dodger Fan/Radio/TV Producer/ News Junky/ Creator of Products/Proud Military Supporter/support Israel/
# 9                                                                                🇺🇸 🇺🇸  Free speech advocate.  Part time MAGA Patriot Booster. Anti MSM propaganda.   🇺🇸 🇺🇸
# 10                 Thought Leadership, Good News, Events, Videos & Podcasts in #FEVoices #EdTech #Apprenticeships #Skills #FE #HE #FutureofWork & #Employability @FECareers
# 11                                                                  💫 Chief Engineer on / #Demvoice1 / #OneV1 Z27/ #ResistanceUnited / #Dems4USA / #RoeVember / *Commentary
# 12              Alone we are strong.\nTogether we are STRONGER!\nProud wife of active duty US Marine.\n🇺🇸🇵🇱\n#MilitaryFamily #GodBlessOurMilitary \n#MAGA #MomOfBoys #GigEm
# 13                                                  🇺🇸 USAF vet ⭐ Vietnam vet ⭐ MAGA ⭐ Trump 2024 ⭐ KAG ⭐ NRA ⭐ Veteran⭐ Patriot ⭐ IFBP ⭐ 1A ⭐ 2A ⭐ FJB ⭐UltraMaga ⭐ No DMs
# 14                                                                                              Devouring entropy. Mutant network node herder http://medium.com/@Asher_Wolf
# 15                    Strong willed softie. Fierce and socially aware, mostly. Ridiculously protective. Champion the underdog. #StrongerTogether💙\n\n#FRESH🌊#ONEV1🌊#wtpBLUE
# 16               Official Twitter account of Texas Tech University. Join the Red Raider conversation! Looking to apply? Go here ➡️ @TxTechAdmission 🔴#FromHereItsPossible⚫️
# 17         Be Smart. Stay Informed. Actively Dissent. Database sorted by topic: http://smartdissent.com #SmartDissent\n\nPRO VACCINE & DEMOCRACY. ANTI STUPIDITY & FASCISM.
# 18                  Founder: wowdevqa: WowDevelopmentQualityAssurance: Pvt: LTD: Nepal: coder programmer tester pentester Software सफ्टवेयर निर्माण वोव देवेलोप्मेंट #Nepal
# 19  Anti-Trump/GOP #Resister.\namateur human being.\ndog/cat friend,  \nintuitive cook,\nanti-Big Money,\n#Independent\n#ClimateChange, \n#FreeInternet, \n#freehealthcare.
# 20                                                                                                                                             #WeAreBG #FreeBrittneyGriner
# 21                 🇺🇸🇺🇸”GOD Bless America”🇺🇸🇺🇸 Love the U.S.A. , Practice Political common sense, Find the humor in everything,Conservative & Patriot,#MAGA #Patriotic #KAG
# 22                 Life-course-development-science-psychiatry-epidemiology-biostat-informatics-behavioral-health-ecosystem-suicide-prevention #WillieKohler-art semantics做人
# 23                                                                                                                                             Common sense. 100% MAGA, KAG
# 24            I am what I am... re-tweets not always endorsements... follows means curious, not party to. God is King. Sister alt. account: @meNabster - #Healing #IFB #FBR
# 25                                                     I follow back #prolife  Just a ole redneck ,#BanSharialaw... #BANHILLARY\n   #pedophiliaISEVIL not lookin for a date
# 26                                                                    I’m sorry did I roll my eyes out loud? … Robbin My Account My Rules! No Bio No Followback! NO DM’s 🌊🌊
# 27                                                             🇺🇸 Biden Harris 🇺🇸 BLM #BeFierce. 🏳️‍🌈 Ally 🏳️‍🌈 #IStandWithUkraine ⭐️ Woke AF! ⛔️maga⛔️     No DMs or Lists
# 28                                            #blacklivesmatter @Marcus4Georgia @beeforGeorgia @staceyabrams 🍑@RenittaShannon 🍑@senatorjen 🍑@cheribeasleync @SenatorWarnock
# 29         #ForUkraine, #Resist, #BLM, #Vaxxed, liberal, autistic, kidney transplant survivor, political nerd, mental health advocate, fighter for equality, truth, justice
#
#     sum(friends_count)
# 0               436449
# 1               186547
# 2               157623
# 3               151432
# 4               133627
# 5                88217
# 6                82262
# 7                76082
# 8                70904
# 9                64121
# 10               62835
# 11               60092
# 12               59711
# 13               59338
# 14               55928
# 15               55046
# 16               53030
# 17               51446
# 18               49529
# 19               48698
# 20               45068
# 21               44565
# 22               43204
# 23               41280
# 24               40136
# 25               39126
# 26               38403
# 27               38372
# 28               38174
# 29               38148

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=top_30_friends['name_username'], width=top_30_friends['sum(friends_count)'])
plt.xlabel('Total friends')
plt.xlim(top_30_friends['sum(friends_count)'].min()-50000, top_30_friends['sum(friends_count)'].max()+50000)
plt.xticks(range(top_30_friends['sum(friends_count)'].min(), top_30_friends['sum(friends_count)'].max(), 100000))
plt.ylabel('name_username')
plt.title('Top 30 most befriended twitterers')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### Verified Accounts

# %%
# Investigate how many verified accounts are there in the dataset 
verified_or_not = sample_df.groupby('verified').agg(count(col('verified'))).toPandas()

# %%
verified_or_not
# Out:
#    verified  count(verified)
# 0      True              285
# 1     False             9282

# %%
verified_or_not['count(verified)'].sum()
# Out:
# 9567

# %%
# adding a percentage column
verified_or_not['percent_of_total'] = (verified_or_not['count(verified)']/verified_or_not['count(verified)'].sum())*100
verified_or_not
# Out:
#    verified  count(verified)  percent of total  percent_of_total
# 0      True              285           2.97899           2.97899
# 1     False             9282          97.02101          97.02101

# %%
# Pie Chart with percentages
plt.pie(verified_or_not['count(verified)'], labels=verified_or_not['count(verified)'], autopct='%1.1f%%')
plt.legend(verified_or_not['verified'])
plt.title('Verified Or Not Users')
plt.show()

# %% [markdown]
# ### Top twitting locations

# %%
# Aggregating location based on reply count
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_loc_reply = sample_df.groupby('location').agg(sum('reply_count')).orderBy('sum(reply_count)',ascending=False).limit(29).toPandas()

# %%
top_30_loc_reply
# Out:
#                   location  sum(reply_count)
# 0                     None            494115
# 1            United States             22494
# 2          California, USA             16651
# 3                      USA             12291
# 4               California             11241
# 5          Los Angeles, CA             10014
# 6             Florida, USA              8708
# 7           Washington, DC              7118
# 8             Portland, OR              6034
# 9                       CA              5845
# 10            Brooklyn, NY              5790
# 11           New York, USA              5594
# 12           Michigan, USA              5449
# 13      Massachusetts, USA              5239
# 14              Texas, USA              5057
# 15              Austin, TX              4369
# 16              Boston, MA              4346
# 17         San Antonio, TX              4276
# 18                   Texas              4273
# 19                 Florida              3955
# 20            San Jose, CA              3742
# 21               Ohio, USA              3737
# 22             Seattle, WA              3526
# 23          Pittsburgh, PA              3512
# 24           Las Vegas, NV              3297
# 25  San Francisco Bay Area              3273
# 26             Oakland, CA              3220
# 27                New York              3132
# 28            New York, NY              3055

# %%
# Creating another location group column with states to aggregate the data 
top_30_loc_reply['loc_grp'] = np.where(top_30_loc_reply['location'].str.contains(r'San F|Cali|CA'), 'CA', 
                                       np.where((top_30_loc_reply['location']=='USA')|(top_30_loc_reply['location']=='United States'),'USA',
                                       np.where(top_30_loc_reply['location'].str.contains(r'DC'), 'DC',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Flor|FL'),'FL',
                                       np.where(top_30_loc_reply['location'].str.contains(r'New Y|NY'), 'NY',
                                       np.where(top_30_loc_reply['location'].str.contains(r'OR'), 'OR',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Mich'), 'MI',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Massa|MA'), 'MA',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Tex|TX'), 'TX',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Ohio'), 'OH',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Pen|PA'), 'PA',
                                       np.where(top_30_loc_reply['location'].str.contains(r'Seat'), 'WA',
                                       np.where(top_30_loc_reply['location'].str.contains(r'NV'), 'NV','')))))))))))))

# Removing the None entry to get a clearer percent frequency distribution across values
top_30_loc_reply = top_30_loc_reply.drop(index=0).reset_index(drop=True)

# %%
top_30_loc_reply
# Out:
#                   location  sum(reply_count) loc_grp
# 0          California, USA             16651      CA
# 1                      USA             12291     USA
# 2               California             11241      CA
# 3          Los Angeles, CA             10014      CA
# 4             Florida, USA              8708      FL
# 5           Washington, DC              7118      DC
# 6             Portland, OR              6034      OR
# 7                       CA              5845      CA
# 8             Brooklyn, NY              5790      NY
# 9            New York, USA              5594      NY
# 10           Michigan, USA              5449      MI
# 11      Massachusetts, USA              5239      MA
# 12              Texas, USA              5057      TX
# 13              Austin, TX              4369      TX
# 14              Boston, MA              4346      MA
# 15         San Antonio, TX              4276      TX
# 16                   Texas              4273      TX
# 17                 Florida              3955      FL
# 18            San Jose, CA              3742      CA
# 19               Ohio, USA              3737      OH
# 20             Seattle, WA              3526      WA
# 21          Pittsburgh, PA              3512      PA
# 22           Las Vegas, NV              3297      NV
# 23  San Francisco Bay Area              3273      CA
# 24             Oakland, CA              3220      CA
# 25                New York              3132      NY
# 26            New York, NY              3055      NY

# %%
print('Unique Locations =',len(top_30_loc_reply['loc_grp'].unique()))
# Out:
# Unique Locations = 13

# %%
# Group By by the grouped locations, top 12 unique locations
top_loc_reply = top_30_loc_reply.groupby('loc_grp')['sum(reply_count)'].sum()

# %%
# Extracting the numbers
pies = []
for i in top_loc_reply:
    pies.append(i)
print(len(pies))
# Out:
# 13

# %%
# Pie Chart
plt.pie(pies, labels=top_loc_reply.index.values, autopct='%1.1f%%')
plt.xlabel('The aggregation on the `None` record has been removed for interpretability')
plt.title('Replys by Location')
plt.show()

# %%
# Aggregating Locations based on retweet count
# Using the sum aggregarion function to add the metric across all tweets posted by the user
top_30_loc_retwt = sample_df.groupby('location').agg(sum('retweet_count')).orderBy('sum(retweet_count)',ascending=False).limit(27).toPandas()

# %%
top_30_loc_retwt
# Out:
#                   location  sum(retweet_count)
# 0                     None             3774519
# 1            United States              200713
# 2          California, USA              133672
# 3                      USA              107405
# 4          Los Angeles, CA               85245
# 5               California               82743
# 6           Washington, DC               65139
# 7             Florida, USA               65115
# 8            New York, USA               56252
# 9             Portland, OR               53385
# 10           Michigan, USA               51963
# 11                      CA               47041
# 12      Massachusetts, USA               44846
# 13              Boston, MA               41858
# 14            Brooklyn, NY               41689
# 15              Texas, USA               39572
# 16                 Florida               39317
# 17         San Antonio, TX               36917
# 18               Ohio, USA               36579
# 19            San Jose, CA               36006
# 20              Austin, TX               34570
# 21          Pittsburgh, PA               31933
# 22  San Francisco Bay Area               31736
# 23                   Texas               31338
# 24             Seattle, WA               28681
# 25       Pennsylvania, USA               26174
# 26            New York, NY               26020

# %%
# Creating another location group column with states to aggregate the data 
top_30_loc_retwt['loc_grp'] = np.where(top_30_loc_retwt['location'].str.contains(r'San F|Cali|CA'), 'CA', 
                                       np.where((top_30_loc_retwt['location']=='USA')|(top_30_loc_retwt['location']=='United States'),'USA',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'DC'), 'DC',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Flor|FL'),'FL',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'New Y|NY'), 'NY',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'OR'), 'OR',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Mich'), 'MI',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Massa|MA'), 'MA',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Tex|TX'), 'TX',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Ohio'), 'OH',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Pen|PA'), 'PA',
                                       np.where(top_30_loc_retwt['location'].str.contains(r'Seat'), 'WA',''))))))))))))

# Removing the None entry to get a clearer percent frequency distribution across values
top_30_loc_retwt = top_30_loc_retwt.drop(index=0).reset_index(drop=True)

# %%
print('Unique Locations =',len(top_30_loc_retwt['loc_grp'].unique()))
# Out:
# Unique Locations = 12

# %%
# Group By by the grouped locations, top 12 unique locations
top_loc_retwt = top_30_loc_retwt.groupby('loc_grp')['sum(retweet_count)'].sum()

# %%
top_loc_retwt
# Out:
# loc_grp
# CA     416443
# DC      65139
# FL     104432
# MA      86704
# MI      51963
# NY     123961
# OH      36579
# OR      53385
# PA      58107
# TX     142397
# USA    308118
# WA      28681
# Name: sum(retweet_count), dtype: int64

# %%
# Extracting the numbers
pies = []
for i in top_loc_retwt:
    pies.append(i)

# %%
# Pie Chart
plt.pie(pies, labels=top_loc_retwt.index.values, autopct='%1.1f%%')
plt.xlabel('The aggregation on the `None` record has been removed for interpretability')
plt.title('Retweets by Location')
plt.show()

# %% [markdown]
# ### Top twitting timelines

# %%
# create new month and year columns for timelines analysis 
sample_df =  sample_df.withColumn('month',split(col('created_at'),' ')[1])
sample_df =  sample_df.withColumn('year',split(col('created_at'),' ')[5])
sample_df.limit(5).toPandas()
# Out:
#                        name      screen_name  verified  friends_count  \
# 0                Live Agile       agile_live     False           3745
# 1                         .     thebongolese     False            980
# 2  🇺🇲 Ultra MAGA Trump Girl  TrumpGi79056629     False           1146
# 3                  Lou Wall  LouWall48323834     False            189
# 4                 Astrosfan    WilliamHartly     False            149
#
#    followers_count             location  \
# 0             3410  Portsmouth, England
# 1             8266               Africa
# 2              691                 None
# 3              268                 None
# 4               11                 None
#
#                                                                                                                                                         description  \
# 0  #Alcoholic #Anxious #Sober. After realising the deep effects of anxiety and addiction I’ve spent years identifying how to win and regain my life. #RecoveryPosse
# 1                                                                                            Professional baby girl, Travel and Documentary Photographer and Auteur
# 2                                                                                                    Conservative, America first, God fearing Patriot.\n 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇲
# 3                                                                   I believe in the Charter of Rights and Freedoms for all Canadians. NO DM’s or I will block you.
# 4                                                                                                                                                              None
#
#    favourites_count  reply_count  retweet_count  \
# 0             11122          0.0           14.0
# 1             15813          NaN            NaN
# 2              5972        201.0         1629.0
# 3             14939        203.0         1647.0
# 4              1084          0.0            1.0
#
#                        created_at  \
# 0  Mon Apr 20 11:41:49 +0000 2020
# 1  Thu Apr 12 15:44:57 +0000 2012
# 2  Mon Apr 25 21:43:27 +0000 2022
# 3  Mon Jan 31 23:05:53 +0000 2022
# 4  Thu Jul 14 16:38:31 +0000 2022
#
#                                                                                                                                                                                                                                                                    tweet_text  \
# 0  @ExtinctionR I'm in Pakistan where 33 million people have been displaced....so yeah. I'm on not on edge. I've actively tipped over. Screaming about climate change for years only to watch in mute despair as half the country sinks. Bridges, roads, homes, schools gone.
# 1                                                                                                                                           Randomly thinking of the Zimbabwe UFO Sighting in 1994. Aliens showed up in a school and told the kids about  “climate change” ….
# 2               BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 3               BREAKING REPORT: Just as Joe Biden prepares to issue EXECUTIVE ORDERS ON CLIMATE CHANGE, NY Times / Siena College Poll reveals only ONE PERCENT of Americans and THREE PERCENT OF DEMOCRATS think climate is THE MOST IMPORTANT PROBLEM facing the Country...
# 4                                                                             Radical tree hugger @krismayes says Climate Change is her top priority. \n\nShe has devoted her life to ending fossil fuels - we have high gas prices because of radical professors like Mayes.
#
#                                name_username month  year
# 0                     Live Agile, agile_live   Apr  2020
# 1                            ., thebongolese   Apr  2012
# 2  🇺🇲 Ultra MAGA Trump Girl, TrumpGi79056629   Apr  2022
# 3                  Lou Wall, LouWall48323834   Jan  2022
# 4                   Astrosfan, WilliamHartly   Jul  2022

# %%
# Monthly Total Sum of Retweets
month_retwt_sum = sample_df.groupby('month').agg(sum('retweet_count')).orderBy('sum(retweet_count)',ascending=False).toPandas()

# %%
month_retwt_sum
# Out:
#    month  sum(retweet_count)
# 0    Apr             1122001
# 1    Jun             1021815
# 2    Mar              914382
# 3    Feb              872083
# 4    May              868891
# 5    Jan              864157
# 6    Jul              859032
# 7    Oct              771627
# 8    Sep              770323
# 9    Aug              725768
# 10   Nov              678590
# 11   Dec              675732

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=month_retwt_sum['month'], width=month_retwt_sum['sum(retweet_count)'])
plt.xlabel('Total Retweets(millions)')
plt.xlim(month_retwt_sum['sum(retweet_count)'].min()-50000, month_retwt_sum['sum(retweet_count)'].max()+50000)
plt.xticks(range(month_retwt_sum['sum(retweet_count)'].min(), month_retwt_sum['sum(retweet_count)'].max(), 100000))
plt.ylabel('Month')
plt.title('Monthly Total Sum of Retweets')
plt.show()

# %%
# Monthly Total Sum of Replies
month_reply_sum = sample_df.groupby('month').agg(sum('reply_count')).orderBy('sum(reply_count)',ascending=False).toPandas()

# %%
month_reply_sum
# Out:
#    month  sum(reply_count)
# 0    Apr            138267
# 1    Jun            126376
# 2    Mar            113409
# 3    Feb            112184
# 4    May            110759
# 5    Jan            109762
# 6    Jul            109168
# 7    Sep             99232
# 8    Aug             96989
# 9    Oct             96331
# 10   Nov             89168
# 11   Dec             82592

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=month_reply_sum['month'], width=month_reply_sum['sum(reply_count)'])
plt.xlabel('Total Replies')
plt.xlim(month_reply_sum['sum(reply_count)'].min()-5000, month_reply_sum['sum(reply_count)'].max()+5000)
plt.xticks(range(month_reply_sum['sum(reply_count)'].min(), month_reply_sum['sum(reply_count)'].max(), 10000))
plt.ylabel('Month')
plt.title('Monthly Total Sum of Replies')
plt.show()

# %%
# Yearly Total Sum of Retweets
year_retwt_sum = sample_df.groupby('year').agg(sum('retweet_count')).orderBy('sum(retweet_count)',ascending=False).toPandas()

# %%
year_retwt_sum
# Out:
#     year  sum(retweet_count)
# 0   2009             1370146
# 1   2020              850170
# 2   2012              822243
# 3   2011              808476
# 4   2017              759052
# 5   2022              719014
# 6   2014              661805
# 7   2016              626412
# 8   2021              618402
# 9   2013              611156
# 10  2015              601629
# 11  2018              600812
# 12  2010              406910
# 13  2019              377879
# 14  2008              264355
# 15  2007               43659
# 16  2023                2265
# 17  2006                  16

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=year_retwt_sum['year'], width=year_retwt_sum['sum(retweet_count)'])
plt.xlabel('Total Retweets(millions)')
plt.xlim(year_retwt_sum['sum(retweet_count)'].min()-100000, year_retwt_sum['sum(retweet_count)'].max()+100000)
plt.xticks(range(year_retwt_sum['sum(retweet_count)'].min(), year_retwt_sum['sum(retweet_count)'].max(), 100000))
plt.ylabel('Year')
plt.title('Yearly Total Sum of Retweets')
plt.show()

# %%
# Yearly Total Sum of Replies
year_reply_sum = sample_df.groupby('year').agg(sum('reply_count')).orderBy('sum(reply_count)',ascending=False).toPandas()

# %%
year_reply_sum
# Out:
#     year  sum(reply_count)
# 0   2009            165682
# 1   2020            103968
# 2   2022            102219
# 3   2011            101453
# 4   2012            100400
# 5   2017             92642
# 6   2021             84011
# 7   2014             82393
# 8   2016             79301
# 9   2013             78239
# 10  2018             75159
# 11  2015             72800
# 12  2010             55636
# 13  2019             49719
# 14  2008             34954
# 15  2007              5433
# 16  2023               224
# 17  2006                 4

# %%
# Bar Chart
plt.figure(figsize=(12, 8))
plt.barh(y=year_reply_sum['year'], width=year_reply_sum['sum(reply_count)'])
plt.xlabel('Total Replies')
plt.xlim(year_reply_sum['sum(reply_count)'].min()-5000, year_reply_sum['sum(reply_count)'].max()+5000)
plt.xticks(range(year_reply_sum['sum(reply_count)'].min(), year_reply_sum['sum(reply_count)'].max(), 10000))
plt.ylabel('Year')
plt.title('Yearly Total Sum of Replies')
plt.show()
